# %%
consumer_key = "uMSZNpPNwN3PyWl1e0eMsEsN3"
consumer_secret = "wZRFwxAKhF12ZYOzLgOb604DL2EtGjno5TnyV40ekQgdziDgVl"
access_token = "1459466517138051077-7SbeIDTZjxCn5vyIqXL9HCeknWkXHF"
access_token_secret = "JgzvdnM40AwBmerizhqrlwp6mAZ3FADEMaJXLCTAhR2BP"
